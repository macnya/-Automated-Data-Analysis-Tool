# %% [markdown]
# <a href="https://colab.research.google.com/github/macnya/-Automated-Data-Analysis-Tool/blob/main/APT3025ASSGNT1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, r2_score

# %%
df_medical = pd.read_csv('/content/KaggleV2.csv')
df_medical.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'KaggleV2.csv', '.ipynb_checkpoints', 'sample_data']

# %%
pd.read_csv('KaggleV2.csv')
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
print(df_medical.columns)
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handcap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
df_medical.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
df_medical.columns = df_medical.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
df_medical.info()
df_medical.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   patientid       110527 non-null  float64
#  1   appointmentid   110527 non-null  int64
#  2   gender          110527 non-null  object
#  3   scheduledday    110527 non-null  object
#  4   appointmentday  110527 non-null  object
#  5   age             110527 non-null  int64
#  6   neighbourhood   110527 non-null  object
#  7   scholarship     110527 non-null  int64
#  8   hipertension    110527 non-null  int64
#  9   diabetes        110527 non-null  int64
#  10  alcoholism      110527 non-null  int64
#  11  handcap         110527 non-null  int64
#  12  sms_received    110527 non-null  int64
#  13  no-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB
#           patientid  appointmentid            age    scholarship  \
# ...

# %%
print(df_medical.columns)
# Out:
# Index(['patientid', 'appointmentid', 'gender', 'scheduledday',
#        'appointmentday', 'age', 'neighbourhood', 'scholarship', 'hipertension',
#        'diabetes', 'alcoholism', 'handcap', 'sms_received', 'no-show'],
#       dtype='object')

# %%
df_medical['no-show'] = df_medical['no-show'].map({'Yes': 1, 'No': 0})

# %%
df_medical = df_medical.drop(columns=['appointmentid', 'patientid'])

# %%
df_medical = pd.get_dummies(df_medical, drop_first=True)

# %%
print(df_medical.columns)
# Out:
# Index(['age', 'scholarship', 'hipertension', 'diabetes', 'alcoholism',
#        'handcap', 'sms_received', 'no-show', 'gender_M',
#        'scheduledday_2015-12-03T08:17:28Z',
#        ...
#        'neighbourhood_SANTOS REIS', 'neighbourhood_SEGURANÇA DO LAR',
#        'neighbourhood_SOLON BORGES', 'neighbourhood_SÃO BENEDITO',
#        'neighbourhood_SÃO CRISTÓVÃO', 'neighbourhood_SÃO JOSÉ',
#        'neighbourhood_SÃO PEDRO', 'neighbourhood_TABUAZEIRO',
#        'neighbourhood_UNIVERSITÁRIO', 'neighbourhood_VILA RUBIM'],
#       dtype='object', length=103663)

# %%
df_medical.columns = df_medical.columns.str.strip().str.lower().str.replace(" ", "_")
print(df_medical.columns)
# Out:
# Index(['age', 'scholarship', 'hipertension', 'diabetes', 'alcoholism',
#        'handcap', 'sms_received', 'no-show', 'gender_m',
#        'scheduledday_2015-12-03t08:17:28z',
#        ...
#        'neighbourhood_santos_reis', 'neighbourhood_segurança_do_lar',
#        'neighbourhood_solon_borges', 'neighbourhood_são_benedito',
#        'neighbourhood_são_cristóvão', 'neighbourhood_são_josé',
#        'neighbourhood_são_pedro', 'neighbourhood_tabuazeiro',
#        'neighbourhood_universitário', 'neighbourhood_vila_rubim'],
#       dtype='object', length=103663)

# %%
df_medical.columns = df_medical.columns.str.strip().str.lower().str.replace(" ", "_").str.replace("-", "_")
print(df_medical.columns)
# Out:
# Index(['age', 'scholarship', 'hipertension', 'diabetes', 'alcoholism',
#        'handcap', 'sms_received', 'no_show', 'gender_m',
#        'scheduledday_2015_12_03t08:17:28z',
#        ...
#        'neighbourhood_santos_reis', 'neighbourhood_segurança_do_lar',
#        'neighbourhood_solon_borges', 'neighbourhood_são_benedito',
#        'neighbourhood_são_cristóvão', 'neighbourhood_são_josé',
#        'neighbourhood_são_pedro', 'neighbourhood_tabuazeiro',
#        'neighbourhood_universitário', 'neighbourhood_vila_rubim'],
#       dtype='object', length=103663)

# %%
if 'no_show' not in df_medical.columns:
    print("Column 'no_show' not found!")
else:
    print("Column exists, proceeding...")
# Out:
# Column exists, proceeding...

# %%
print(df_medical.columns)
# Out:
# Index(['age', 'scholarship', 'hipertension', 'diabetes', 'alcoholism',
#        'handcap', 'sms_received', 'no_show', 'gender_m',
#        'scheduledday_2015_12_03t08:17:28z',
#        ...
#        'neighbourhood_santos_reis', 'neighbourhood_segurança_do_lar',
#        'neighbourhood_solon_borges', 'neighbourhood_são_benedito',
#        'neighbourhood_são_cristóvão', 'neighbourhood_são_josé',
#        'neighbourhood_são_pedro', 'neighbourhood_tabuazeiro',
#        'neighbourhood_universitário', 'neighbourhood_vila_rubim'],
#       dtype='object', length=103663)
